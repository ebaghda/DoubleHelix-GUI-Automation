# %%
import time
import pyautogui as gui
"""
time.sleep(5)
x, y = gui.position()
px = gui.pixel(x,y)
print(x, ',', y)
print(x,',', y,',', px)
raise SystemExit
"""
# Out:
# "\ntime.sleep(5)\nx, y = gui.position()\npx = gui.pixel(x,y)\nprint(x, ',', y)\nprint(x,',', y,',', px)\nraise SystemExit\n"

# %%
def process_videos(vid_range):
    for vid_idx in list(range(int(16/2),vid_range)):
        
        # Set Fail-Safes and initialize
        gui.PAUSE = 0.75 #set a pause time of 
        gui.FAILSAFE = True # set a fail-safe method - moving the mouse to a screen corner will cause an exception, ending the script
        for i  in range(5):
            gui.hotkey('win', 'm')
            pass
        gui.hotkey('win', 'e') #open the file explorer
        gui.hotkey('win', 'up')
        time.sleep(0.7)
        gui.press('f4') #activate the navigation bar
        gui.hotkey('ctrl', 'a') #select the text
        gui.typewrite("L:\\2024.05.28") #type the experiment date folder
        gui.press('enter') #navigate to the experiment date folder
        gui.press('escape') #escape the navigation bar
        gui.PAUSE = 0.1 #set a pause time of 0.3

        gui.hotkey('down') #initialize file highlighting
        gui.hotkey('up') #correct to first highlighted file

        i1=1 #initialize file counter
        while i1 < len(range(vid_idx)): #loop for video file selection
            gui.hotkey('down') #move selection down
            gui.hotkey('down') #move selection down (need two to account for the generated CSV)
            i1+=1 #increment index
        gui.pause = 10
        gui.press('enter') #load the highlighted video in FIJI
        gui.pause = 0.5
        gui.moveTo(1079, 10, 0.5) #select the file explorer window
        gui.click() #select the file explorer window
        gui.hotkey('ctrl', 'w') #close the file explorer
       
        time.sleep(2) #allow splash window to open
        while gui.pixelMatchesColor(1130, 647, (255, 255, 255), tolerance=10) is False:
            time.sleep(1)
            gui.move(-2, -2)
            gui.move(2, 2)
        gui.moveTo(650, 140, 0.5) #select the splash window
        gui.moveTo(1250, 630, 0.5) #open with current settings
        gui.click() #open .nd2 file with current settings
        #time.sleep(90) #wait for the video to load
        #adjust contrast and properties
        gui.moveTo(1650, 630, 0.5) #move cursor to the video window
        while gui.pixelMatchesColor(1650, 630, (2,2,2), tolerance=50) is False: #check that the vidoe is loaded by testing a pixel value
                #gui.alert(text='Video loading...', title='Hold on', button='OK') #display error message
                #raise SystemExit #end program
                time.sleep(5)
                gui.move(-2, -2)
                gui.move(2, 2)
                #gui.click(979, 572)
        gui.click()
        #gui.hotkey('shift', 'c') #open the FIJI brightness and contrast window
        #gui.moveTo(800, 370, 0.5) #move to the "Apply" button
        #gui.click()
        #gui.moveTo(910, 325, 0.5) #move cursor to the "OK" confirmation option
        #gui.click()

        gui.moveTo(1650, 630, 0.5) #move cursor to the video window
        gui.click()
        gui.hotkey('shift', 'p') #open the FIJI properties window
        gui.moveTo(950, 420, 0.5) #move to the framerate dialog box
        gui.click()
        gui.hotkey('ctrl', 'a') #select the text in the framerate dialog box
        gui.press('backspace') #delete the text in the framerate dialog box
        gui.typewrite("1 sec") #type "1 sec" in the framerate dialog box
        gui.moveTo(1000, 520, 0.5) #move to the "OK" button
        gui.click()

        # open 3DTRAX
        gui.moveTo(1300, 20, 0.5) #move cursor to the video header
        time.sleep(0.5) #wait 0.5 seconds
        gui.dragTo(1300, 150, 1, button='left') #drag the window down to access the main menu

        gui.moveTo(1389, 15, 0.5)  #select the FIJI main page
        gui.click()
        gui.hotkey('win', 'up')
        
        gui.moveTo(488, 32, 0.5)  #select the "3DTRAX" FIJI menu item
        gui.click()
        gui.moveTo(498, 59, 0.5) #select the 3DTRAX Analysis item
        gui.click()
        while gui.pixelMatchesColor(770, 198, (9, 138, 239), tolerance=10) is False:
            time.sleep(3) #wait for the 3DTRAX page to open

        #open the calibration file
        gui.moveTo(1030, 500, 0.5) #move cursor to the "Open" calibration file button in 3DTRAX
        gui.click()
        gui.sleep(0.5)
        gui.typewrite(r"L:\2024.05.28\calibration_003_29-May-2024_13-23-35(78Elements).3DTRAX.calibration") #input the calibration file name
        gui.press("enter") #import the calibration file into 3DTRAX

        #Select the video
        gui.moveTo(1100,560, 0.5) #select analysis method for localization
        gui.click()
        gui.moveTo(1100, 580, 0.5) #set to sparse emitter
        gui.click()

        gui.moveTo(1020, 600, 0.5) #refresh video source to currently open video file
        gui.click()

        gui.moveTo(1190, 715, 0.5) #run analysis

        gui.click() #RUN ANALYSIS
        while gui.pixelMatchesColor(1155, 673, (215, 228, 241), tolerance=10) is False:
            time.sleep(1)
            gui.move(-2, -2)
            gui.move(2, 2)
            if gui.pixelMatchesColor(1058, 904, (208, 157, 0), tolerance=10) is True:
                break
        gui.moveTo(1150, 675, 0.5) #save results
        gui.click() #click "Save"
        time.sleep(3)
        gui.moveTo(1893, 14, 0.5) #close FIJI
        gui.click()
        gui.sleep(1)  #wait for FIJI to close
        gui.moveTo(980, 345, 0.5) #don't save changes to video
        gui.click()

        gui.sleep(2)  #wait for FIJI to close

# %%
process_videos(20)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 process_videos(20)
#
# Cell In[2], line 95, in process_videos(vid_range)
#      92 gui.press("enter") #import the calibration file into 3DTRAX
#      94 #Select the video
# ---> 95 gui.moveTo(1100,560, 0.5) #select analysis method for localization
#      96 gui.click()
#      97 gui.moveTo(1100, 580, 0.5) #set to sparse emitter
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:593, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
# --> 593     failSafeCheck()
#     594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:1734, in failSafeCheck()
#    1732 def failSafeCheck():
#    1733     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1734         raise FailSafeException(
#    1735             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1736         )
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
"""
time.sleep(5)
x, y = gui.position()
print(x,y)
px = gui.pixel(x,y)
print(px)
"""
print(vid_idx)
